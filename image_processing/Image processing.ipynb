# %% [markdown]
# ## Image processing | Basics

# %%
# %matplotlib inline

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import skimage

# %%
img = Image.open('building.png')
img = np.array(img)

plt.imshow(img, cmap ='gray')
plt.show()

# %%
#TODO
img[150:450, 350:670] = 0
img_blocked = img

plt.imshow(img_blocked, cmap ='gray')
plt.show()

# %% [markdown]
# ## Image processing | Convolution

# %%
# %matplotlib inline

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import skimage

# %%
img = Image.open('building.png')

plt.imshow(img, cmap ='gray')
plt.show()

# %%
from skimage.filters import gaussian, sobel_h, sobel_v

img = np.array(img)
img_blur = gaussian(img, sigma=1)

plt.imshow(img_blur, cmap ='gray')
plt.show()

# %%
edges = sobel_h(img)

plt.imshow(edges, cmap ='gray')
plt.imshow(edges > 0.1, cmap ='gray')
plt.show()
